# %%
import numpy as np
import pandas as pd

pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 0f437949513225922d851e9581723d82120684a6
# python           : 3.8.10.final.0
# python-bits      : 64
# OS               : Darwin
# OS-release       : 18.7.0
# Version          : Darwin Kernel Version 18.7.0: Tue Jun 22 19:37:08 PDT 2021; root:xnu-4903.278.70~1/RELEASE_X86_64
# machine          : x86_64
# processor        : i386
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 2.0.3
# numpy            : 1.24.4
# pytz             : 2023.3
# dateutil         : 2.8.2
# setuptools       : 56.0.0
# pip              : 25.0.1
# Cython           : None
# pytest           : 6.0.1
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 3.1.2
# IPython          : 8.12.2
# pandas_datareader: None
# bs4              : 4.12.1
# bottleneck       : None
# brotli           : None
# fastparquet      : None
# fsspec           : 2023.9.0
# gcsfs            : None
# matplotlib       : 3.7.2
# numba            : None
# numexpr          : None
# odfpy            : None
# openpyxl         : None
# pandas_gbq       : None
# pyarrow          : 13.0.0
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.10.1
# snappy           : None
# sqlalchemy       : 2.0.36
# tables           : None
# tabulate         : 0.9.0
# xarray           : None
# xlrd             : None
# zstandard        : 0.23.0
# tzdata           : 2023.3
# qtpy             : None
# pyqt5            : None

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.752617 -1.563886 -0.424161 -0.547066
# 2013-01-02  1.258815 -1.879826  0.486040 -0.457800
# 2013-01-03  2.702998 -0.305122 -2.491232 -1.292543
# 2013-01-04 -0.425900  0.911922  0.052108 -0.844296
# 2013-01-05  0.510430 -0.487296  0.950646  0.556505
# 2013-01-06 -0.112669 -1.378818 -0.012247 -0.566647

# %%
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'foo'}) 
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  1.752617 -1.563886 -0.424161 -0.547066
# 2013-01-02  1.258815 -1.879826  0.486040 -0.457800
# 2013-01-03  2.702998 -0.305122 -2.491232 -1.292543
# 2013-01-04 -0.425900  0.911922  0.052108 -0.844296
# 2013-01-05  0.510430 -0.487296  0.950646  0.556505

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.425900  0.911922  0.052108 -0.844296
# 2013-01-05  0.510430 -0.487296  0.950646  0.556505
# 2013-01-06 -0.112669 -1.378818 -0.012247 -0.566647

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
4+5
# Out:
# 9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 1.75261655, -1.56388564, -0.42416079, -0.54706594],
#        [ 1.25881507, -1.87982553,  0.4860399 , -0.45779987],
#        [ 2.7029976 , -0.30512239, -2.49123194, -1.29254276],
#        [-0.42590035,  0.91192153,  0.05210796, -0.84429586],
#        [ 0.51042996, -0.48729635,  0.95064618,  0.55650495],
#        [-0.1126689 , -1.3788179 , -0.01224703, -0.56664687]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
# create a dataframe with geo-numeric data
data = pd.DataFrame({'region': ['east', 'west', 'north', 'south'],
                     'gdp': [2000, 3245, 3421, 2099]})
data['gdp']
# Out:
# 0    2000
# 1    3245
# 2    3421
# 3    2099
# Name: gdp, dtype: int64

# %%
data.columns
# Out:
# Index(['region', 'gdp'], dtype='object')

# %%
data.iloc(0)

# %%
for x in data.iloc[0]:
    print(x)
# Out:
# east
# 2000

# %%
data['gdp'] = 2 * data['gdp']

# %%
data['gdp']
# Out:
# 0    4000
# 1    6490
# 2    6842
# 3    4198
# Name: gdp, dtype: int64

# %%
# sorting on a Dataframe
data.sort_values(by='gdp', ascending=False)
# Out:
#   region   gdp
# 2  north  6842
# 1   west  6490
# 3  south  4198
# 0   east  4000

# %%
gdp = data.gdp.iloc[:]
gdp
# Out:
# 0    4000
# 1    6490
# 2    6842
# 3    4198
# Name: gdp, dtype: int64

# %%
np.average(gdp, axis=0)
# Out:
# 5382.5
